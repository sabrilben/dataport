# %% [markdown]
# # Stock Price Prediction
#
# In this project, we will try to predict future stock price using LSTM (Long-Short Term Memory) and GRU (Gated Recurrent Units). We will use Tesla Stock Prices for this project, you can click the link below to access the dataset. The dataset consist of 7 columns:
# * Date (Jan 2012-Jun 2023)
# * Open
# * High
# * Low
# * Close
# * Adj Close
# * Volume
#
# Dataset:
# * https://www.kaggle.com/datasets/joykimaiyo18/tesla-stock-prices-latest

# %% [markdown]
# ## Import Library & Dataset

# %%
# Importing the libraries
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import pandas as pd
from tensorflow.keras.optimizers import SGD
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
import math
from sklearn.metrics import mean_squared_error

# %%
# Some functions to help out with this code
def plot_predictions(test,predicted):
    plt.plot(test, color='red',label='Real Tesla Stock Price')
    plt.plot(predicted, color='blue',label='Predicted Tesla Stock Price')
    plt.title('Tesla Stock Price Prediction')
    plt.xlabel('Time')
    plt.ylabel('Tesla Stock Price')
    plt.legend()
    plt.show()

def return_rmse(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))

# %%
# First, we get the data
dataset = pd.read_csv('D:/Working Directory/Python/Final Project DS - Kelas.Work/Tesla Stock Prices Latest/TSLA (1).csv', index_col='Date', parse_dates=['Date'])
dataset.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2012-01-03  1.929333  1.966667  1.843333  1.872000   1.872000  13921500
# 2012-01-04  1.880667  1.911333  1.833333  1.847333   1.847333   9451500
# 2012-01-05  1.850667  1.862000  1.790000  1.808000   1.808000  15082500
# 2012-01-06  1.813333  1.852667  1.760667  1.794000   1.794000  14794500
# 2012-01-09  1.800000  1.832667  1.741333  1.816667   1.816667  13455000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2872 entries, 2012-01-03 to 2023-06-01
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2872 non-null   float64
#  1   High       2872 non-null   float64
#  2   Low        2872 non-null   float64
#  3   Close      2872 non-null   float64
#  4   Adj Close  2872 non-null   float64
#  5   Volume     2872 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 157.1 KB

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Create subplots for each column
n_cols = dataset.shape[1]
fig, axes = plt.subplots(n_cols, 1, figsize=(16, 4 * n_cols))

for i, col in enumerate(dataset.columns):
    dataset[col].plot(ax=axes[i], label=col)
    axes[i].set_ylabel(f'{col}')
    axes[i].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Analysis:**
# * The charts between Open, High, Low, Close, and Adj Close have similar pattern. This is because they are all related to the same trading period of a stock and are derived from the same trading data.
# * Since these prices are all based on the same set of trades within a specific period, their movements are typically in sync, resulting in similar chart patterns.
# * The Volume chart, however, shows the number of shares traded and can have a different pattern compared to price charts.
#
# * From the chart we can see that before 2020, Tesla stock prices are relatively stable.
# * Then after 2020, there is a significant increase on the prices. And it become fluctuatively changes over the years
# * Although the prices are relatively stable in 2020, we can see in the Volume chart that the trading activity are fluctuative across all years. Indicating volatility and changes in investor interest/sentiment towards Tesla's stock.

# %% [markdown]
# ## Prepare Data for Prediction Model

# %%
# Checking for missing values
training_set = dataset[:'2022'].iloc[:,1:2].values
test_set = dataset['2023':].iloc[:,1:2].values

# %%
# We have chosen 'High' attribute for prices. Let's see what it looks like
dataset["High"][:'2022'].plot(figsize=(16,4),legend=True)
dataset["High"]['2023':].plot(figsize=(16,4),legend=True)
plt.legend(['Training set (Before 2023)','Test set (2023 and beyond)'])
plt.title('Tesla stock price')
plt.show()

# %%
# Scaling the training set
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)
training_set_scaled.shape
# Out:
# (2768, 1)

# %% [markdown]
# ## LSTM Model

# %%
# Since LSTMs store long term memory state, we create a data structure with 60 timesteps and 1 output
# So for each element of training set, we have 60 previous training set elements 
X_train = []
y_train = []
for i in range(60,2768):
    X_train.append(training_set_scaled[i-60:i,0])
    y_train.append(training_set_scaled[i,0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
# Reshaping X_train for efficient modelling
X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))

# %%
# The LSTM architecture
model_lstm = Sequential()
# First LSTM layer with Dropout regularisation
model_lstm.add(LSTM(units=64, return_sequences=True, input_shape=(X_train.shape[1],1)))
model_lstm.add(Dropout(0.2))
# Second LSTM layer
model_lstm.add(LSTM(units=64, return_sequences=True))
model_lstm.add(Dropout(0.2))
# Third LSTM layer
model_lstm.add(LSTM(units=64, return_sequences=True))
model_lstm.add(Dropout(0.2))
# Fourth LSTM layer
model_lstm.add(LSTM(units=64))
model_lstm.add(Dropout(0.2))
# The output layer
model_lstm.add(Dense(units=1))

# Compiling the RNN
model_lstm.compile(optimizer='adam',loss='mean_squared_error')
# Fitting to the training set
model_lstm.fit(X_train,y_train,epochs=100,batch_size=32)
# Out:
# D:\Apps\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 15s 54ms/step - loss: 0.0129
# Epoch 2/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - loss: 0.0028
# Epoch 3/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 0.0019
# Epoch 4/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0017
# Epoch 5/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 0.0017
# Epoch 6/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0018
# Epoch 7/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 0.0015
# Epoch 8/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - loss: 0.0015
# Epoch 9/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 0.0014
# Epoch 10/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - loss: 0.0014
# ...

# %%
# Now to get the test set ready in a similar way as the training set.
# The following has been done so forst 60 entires of test set have 60 previous values which is impossible to get unless we take the whole 
# 'High' attribute data for processing
dataset_total = pd.concat((dataset["High"][:'2022'],dataset["High"]['2023':]),axis=0)
inputs = dataset_total[len(dataset_total)-len(test_set) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = sc.transform(inputs)

# %%
inputs.shape
# Out:
# (164, 1)

# %%
# Preparing X_test and predicting the prices
X_test = []
for i in range(60,164):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
predicted_stock_price = model_lstm.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step

# %%
# Visualizing the results for LSTM
plot_predictions(test_set,predicted_stock_price)

# %%
# Evaluating our model
return_rmse(test_set,predicted_stock_price)
# Out:
# The root mean squared error is 7.394324246639076.

# %% [markdown]
# ## GRU Model

# %%
# The GRU architecture
LSTM_GRU = Sequential()
# First GRU layer with Dropout regularisation
LSTM_GRU.add(GRU(units=64, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
LSTM_GRU.add(Dropout(0.2))
# Second GRU layer
LSTM_GRU.add(GRU(units=64, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
LSTM_GRU.add(Dropout(0.2))
# Third GRU layer
LSTM_GRU.add(GRU(units=64, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
LSTM_GRU.add(Dropout(0.2))
# Fourth GRU layer
LSTM_GRU.add(GRU(units=64, activation='tanh'))
LSTM_GRU.add(Dropout(0.2))
# The output layer
LSTM_GRU.add(Dense(units=1))
# Compiling the RNN
LSTM_GRU.compile(optimizer='rmsprop',loss='mean_squared_error')
# Fitting to the training set
LSTM_GRU.fit(X_train,y_train,epochs=100,batch_size=32)
# Out:
# Epoch 1/100
# D:\Apps\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 12s 61ms/step - loss: 0.0144
# Epoch 2/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 0.0030
# Epoch 3/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 0.0026
# Epoch 4/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 0.0021
# Epoch 5/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 0.0021
# Epoch 6/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 0.0020
# Epoch 7/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 0.0021
# Epoch 8/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 0.0019
# Epoch 9/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - loss: 0.0019
# Epoch 10/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 0.0020
# ...

# %%
# Preparing X_test and predicting the prices
X_test = []
for i in range(60,164):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
GRU_predicted_stock_price = LSTM_GRU.predict(X_test)
GRU_predicted_stock_price = sc.inverse_transform(GRU_predicted_stock_price)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 244ms/step

# %%
# Visualizing the results for GRU
plot_predictions(test_set,GRU_predicted_stock_price)

# %%
# Evaluating GRU
return_rmse(test_set,GRU_predicted_stock_price)
# Out:
# The root mean squared error is 9.5555346736053.

# %% [markdown]
# **Looks like LSTM works better than GRU in this case, as it has lower RMSE.**
